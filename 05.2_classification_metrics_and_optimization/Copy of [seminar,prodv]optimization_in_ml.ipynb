# %% [markdown]
# <p style="align: center;"><img align=center src="https://s8.hostingkartinok.com/uploads/images/2018/08/308b49fcfbc619d629fe4604bceb67ac.jpg" width=500 height=450/></p>
#
# <h3 style="text-align: center;"><b>"Глубокое обучение". Продвинутый поток</b></h3>
#
# <h1 style="text-align: center;"><b>Семинар 5. Оптимизация в машинном обучении</b></h1>
#
# Сегодня мы поработаем с оптимизацией в линейных алгоритмах (линейная регрессия и логистическая регрессия), попутно потренировавшись ООП в Python.

# %%
import numpy as np
import pandas as pd
from sklearn import datasets, linear_model
import scipy.linalg as sla
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Линейная регрессия
#
# Линейные методы предполагают, что между признаками объекта и целевой переменной существует линейная зависимость, то есть
# $$y = w_1 x_1 + w_2 x_2 + ... + w_k x_k + b, $$ где $у$ --- целевая переменная (что мы хотим предсказать), $x_i$ --- признак объекта $х$, $w_i$ --- вес $i$-го признака, $b$ --- bias (смещение, свободный член)
#
# Часто предполагают, что объект $х$ содержит в себе фиктивный признак, который всегда равен 1, тогда bias это есть вес этого признака. В этом случае формула принимает простой вид:
# $$y = \langle w, x \rangle,$$
# где $\langle \cdot, \cdot \rangle$ -- скалярное произведение векторов.
#
# В матричной форме, в случае, когда у нас есть n объектов формулу можно переписать следующим образом:$$ Y = Xw, $$ где $Y$ -- вектор размера $n$, $X$ --- матрица объекты-признаки размера $n \times k$, $w$ -- вектор весов размера $k$.
#
# Решение по методу наименьших квадратов дает $$ w = (X^TX)^{-1}X^TY $$

# %% [markdown]
# Реализуем класс линейной регрессии с помощью этой формулы.

# %%
class MyLinearRegression:
    
    def __init__(self):
        pass
    
    def fit(self, X, y):
        # Принимает на вход X, y и вычисляет веса по данной выборке
        # Не забудьте про фиктивный признак равный 1!
        
        n, k = X.shape
        X_train = np.hstack((X, np.ones((n, 1))))
        
        self.w = np.linalg.inv(X_train.T @ X_train) @ X_train.T @ y
        
    def predict(self, X):
        # Принимает на вход X и возвращает ответы модели
        
        n, k = X.shape
        X_test = np.hstack((X, np.ones((n, 1))))
        y_pred = X_test @ self.w
        return y_pred
    
    def get_weights(self):
        return self.w

# %% [markdown]
# ### Тестирование
# Сгенерируем искусственные данные для теста нашей модели

# %%
from sklearn.model_selection import train_test_split

# %%
# generate data
X = np.linspace(-5, 5, 100)
y = 10 * X - 7 + np.random.randn(100) * 10

# split data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5)

# %%
plt.figure(figsize=(10, 5))
plt.plot(X, 10 * X - 7, label='real')
plt.scatter(X_train, y_train, label='train')
plt.scatter(X_test, y_test, label='test')
plt.legend()
plt.show()

# %% [markdown]
# Обучим модель на трейне и предскажем результаты на тесте

# %%
regressor = MyLinearRegression()

# Ваш код здесь

regressor.fit(X_train[:, np.newaxis], y_train)

predictions = regressor.predict(X_test[:, np.newaxis])
w = regressor.get_weights()

# %%
plt.figure(figsize=(10, 5))
plt.plot(X, 10 * X - 7, label='real')

plt.scatter(X_train, y_train, label='train')
plt.scatter(X_test, y_test, label='test')
plt.plot(X, X * w[0] + w[-1], label='predicted')
plt.legend()
plt.show()

# %% [markdown]
# ### Результаты

# %%
from sklearn.metrics import mean_squared_error

train_predictions = regressor.predict(X_train[:, np.newaxis])
test_predictions = regressor.predict(X_test[:, np.newaxis])

print('Train MSE: ', mean_squared_error(y_train, train_predictions))
print('Test MSE: ', mean_squared_error(y_test, test_predictions))
# Out:
# Train MSE:  105.10709476411466
# Test MSE:  96.63724503890874

# %% [markdown]
# ## Градиентная оптимизация
# Как уже было упомянуто на лекции, обращение матрицы --- очень долгая операция. Кроме того, обратная матрица не всегда существует. По этим причинам, мы воспользуемся методом градиентного спуска для оптимизации эмпирического риска.
#
# Как правило, вместо градиентного спуска используют стохастический градиентный спуск: выбирают случайный элемент обучающей выборки и изменяют коэффициенты модели по направлению антиградиента функции потерь на этом примере.
#
# Реализуйте новый класс линейной регрессии, в которой проведите оптимизацию методом стохастического градиентного спуска. Используйте наследование классов.

# %%
class MyGradientLinearRegression(MyLinearRegression):
    def __init__(self):
        super().__init__() #в данном случае ничего не делает
        self.w = None
    
    def fit(self, X, y, lr=0.01, n_epoch=10):
        # Принимает на вход X, y и вычисляет веса по данной выборке
        # Не забудьте про фиктивный признак равный 1!
        
        print('Input shape: ', X.shape)
        n, k = X.shape
        
        if self.w is None:
            self.w = np.random.randn(k + 1)
        
        X_train = np.hstack((X, np.ones((n, 1))))
        print('Design matrix shape (X_train.shape): ', X_train.shape, '\n')
        
        losses = []
        
        for iter_num in range(n_epoch):
            y_pred = self.predict(X)

            losses.append(mean_squared_error(y_pred, y))

            grad = np.zeros_like(self.w)

            # batch (full) gradient descent
            for x, prediction, label in zip(X_train, y_pred, y):                   
                grad += 2 * (prediction - label) * x
            grad /= n
            
            self.w -= lr * grad

            print('Epoch ', iter_num+1, ' | ', 'loss: ', losses[-1])
            
            
        return losses

# %% [markdown]
# ### Тестируем. Поиграйтесь с количеством эпох

# %%
regressor = MyGradientLinearRegression()

l = regressor.fit(X_train[:, np.newaxis], y_train, n_epoch=100)

predictions = regressor.predict(X_test[:, np.newaxis])
w = regressor.get_weights()
# Out:
# Input shape:  (50, 1)
# Design matrix shape (X_train.shape):  (50, 2)
#
# Epoch  1  |  loss:  816.7999715957999
# Epoch  2  |  loss:  639.3139453998328
# Epoch  3  |  loss:  509.18111372833516
# Epoch  4  |  loss:  413.63871263872437
# Epoch  5  |  loss:  343.3688626603161
# Epoch  6  |  loss:  291.56854243556813
# Epoch  7  |  loss:  253.2706520036744
# Epoch  8  |  loss:  224.84837595241737
# Epoch  9  |  loss:  203.65335871846912
# Epoch  10  |  loss:  187.75156513537527
# Epoch  11  |  loss:  175.7304529595669
# Epoch  12  |  loss:  166.5582044257143
# Epoch  13  |  loss:  159.4809618413523
# Epoch  14  |  loss:  153.94780683125384
# Epoch  15  |  loss:  149.5559929667059
# Epoch  16  |  loss:  146.0109637542413
# Epoch  17  |  loss:  143.0971642284886
# Epoch  18  |  loss:  140.65673209679
# Epoch  19  |  loss:  138.57394112527427
# Epoch  20  |  loss:  136.76384379153507
# Epoch  21  |  loss:  135.16397950402106
# Epoch  22  |  loss:  133.7283207663234
# Epoch  23  |  loss:  132.4228531069257
# Epoch  24  |  loss:  131.22234771186132
# Epoch  25  |  loss:  130.1080047759287
# Epoch  26  |  loss:  129.0657325173223
# Epoch  27  |  loss:  128.08489026041192
# Epoch  28  |  loss:  127.15737031825309
# Epoch  29  |  loss:  126.27692722585503
# Epoch  30  |  loss:  125.43868756404876
# Epoch  31  |  loss:  124.63879163709588
# Epoch  32  |  loss:  123.8741314245305
# Epoch  33  |  loss:  123.14215883285222
# Epoch  34  |  loss:  122.44074528462507
# Epoch  35  |  loss:  121.76807880140014
# Epoch  36  |  loss:  121.12258847376526
# Epoch  37  |  loss:  120.50288893984023
# Epoch  38  |  loss:  119.9077394850593
# Epoch  39  |  loss:  119.33601382995292
# Epoch  40  |  loss:  118.78667773401092
# Epoch  41  |  loss:  118.25877231855196
# Epoch  42  |  loss:  117.75140157719136
# Epoch  43  |  loss:  117.26372295546602
# Epoch  44  |  loss:  116.79494018266763
# Epoch  45  |  loss:  116.3442977590467
# Epoch  46  |  loss:  115.9110766622541
# Epoch  47  |  loss:  115.4945909542189
# Epoch  48  |  loss:  115.09418505533243
# Epoch  49  |  loss:  114.7092315153654
# Epoch  50  |  loss:  114.33912915622697
# Epoch  51  |  loss:  113.98330149503786
# Epoch  52  |  loss:  113.64119538035922
# Epoch  53  |  loss:  113.3122797922216
# Epoch  54  |  loss:  112.99604476960832
# Epoch  55  |  loss:  112.69200043855645
# Epoch  56  |  loss:  112.39967612099191
# Epoch  57  |  loss:  112.11861950950338
# Epoch  58  |  loss:  111.84839589698359
# Epoch  59  |  loss:  111.58858745279706
# Epoch  60  |  loss:  111.33879253913524
# Epoch  61  |  loss:  111.09862506269162
# Epoch  62  |  loss:  110.86771385787358
# Epoch  63  |  loss:  110.64570209856656
# Epoch  64  |  loss:  110.43224673605937
# Epoch  65  |  loss:  110.22701796118027
# Epoch  66  |  loss:  110.02969868902186
# Epoch  67  |  loss:  109.83998406488284
# Epoch  68  |  loss:  109.65758099024198
# Epoch  69  |  loss:  109.48220766772428
# Epoch  70  |  loss:  109.31359316413241
# Epoch  71  |  loss:  109.1514769907046
# Epoch  72  |  loss:  108.99560869983004
# Epoch  73  |  loss:  108.84574749751322
# Epoch  74  |  loss:  108.70166187092278
# Epoch  75  |  loss:  108.56312923040464
# Epoch  76  |  loss:  108.42993556537131
# Epoch  77  |  loss:  108.3018751135115
# Epoch  78  |  loss:  108.17875004279118
# Epoch  79  |  loss:  108.06037014574068
# Epoch  80  |  loss:  107.94655254554682
# Epoch  81  |  loss:  107.83712141348873
# Epoch  82  |  loss:  107.7319076972756
# Epoch  83  |  loss:  107.63074885986278
# Epoch  84  |  loss:  107.53348862834044
# Epoch  85  |  loss:  107.43997675250448
# Epoch  86  |  loss:  107.35006877273568
# Epoch  87  |  loss:  107.26362579682674
# Epoch  88  |  loss:  107.18051428541251
# Epoch  89  |  loss:  107.10060584567078
# Epoch  90  |  loss:  107.02377703297466
# Epoch  91  |  loss:  106.94990916019006
# Epoch  92  |  loss:  106.87888811432303
# Epoch  93  |  loss:  106.81060418023397
# Epoch  94  |  loss:  106.74495187114604
# Epoch  95  |  loss:  106.6818297656857
# Epoch  96  |  loss:  106.62114035120418
# Epoch  97  |  loss:  106.56278987313686
# Epoch  98  |  loss:  106.50668819016872
# Epoch  99  |  loss:  106.4527486349814
# Epoch  100  |  loss:  106.40088788036745

# %%
plt.figure(figsize=(10, 5))
plt.plot(X, 10 * X - 7, label='real')

plt.scatter(X_train, y_train, label='train')
plt.scatter(X_test, y_test, label='test')
plt.plot(X, X * w[0] + w[-1], label='predicted')
plt.legend()
plt.show()

# %%
plt.plot(l)

# %% [markdown]
# ## Что можно делать дальше
#
# * Реализовать стохастический градиентный спуск
# * Реализовать Ridge-регрессию (к функции потерь прибавляется слагаемое $C||w||$).

# %%
class MyStochasticGradientLinearRegression(MyLinearRegression):
    def __init__(self):
        super().__init__()  # does nothing in this case
        self.w = None
    
    def fit(self, X, y,
            lr=0.01, n_epoch=100,
            batch_size = 1,
            early_stopping = None,
            print_every = 1):
        # Input: X, y
        # Computes the weights for this sample
        
        assert (early_stopping is None) or (early_stopping < n_epoch)
        assert batch_size <= X.shape[0], \
        "batch_size = {} should be less than the number of observations = {}\
        ".format(batch_size, X.shape[0])
        assert print_every <= n_epoch
        
        print('Input shape: ', X.shape)
        n, k = X.shape
        
        if self.w is None:
            self.w = np.random.randn(k + 1)
        
        X_train = np.hstack((X, np.ones((n, 1))))
        print('Design matrix shape (X_train.shape): ', X_train.shape, '\n')
        
        losses = []
        
        for iter_num in range(n_epoch):
            
            # making predictions with weights from previous iteration
            y_pred = self.predict(X)
            losses.append(mean_squared_error(y_pred, y))
            
            # printing the losses
            if (iter_num + 1) % print_every == 0:
                print('Epoch ', iter_num+1, ' | ', 'loss: ', losses[-1])

            # choosing the elements for the gradient step
            ids = np.random.randint(low=0, high=X_train.shape[0],  size=batch_size)

            # mini-batch stochastic gradient descent
            grad = np.zeros_like(self.w)
            for x, prediction, label in zip(X_train[ids, :], y_pred[ids], y[ids]):                   
                grad += 2 * (prediction - label) * x
            grad /= batch_size            
            self.w -= lr * grad

            # early stopping
            if early_stopping and (early_stopping < iter_num):
                last_losses = np.array(losses[-early_stopping:]) 
                if (last_losses > losses[-(early_stopping+1)]).all():
                    print('------------------------')
                    print('Best epoch ', iter_num - early_stopping, ' | ',
                          'loss: ', losses[- (early_stopping+1)])
                    break
            
        return losses

# %%
regressor = MyStochasticGradientLinearRegression()

l = regressor.fit(X_train[:, np.newaxis], y_train,
                  n_epoch=10000, batch_size=1,
                  early_stopping = 50, print_every=50)

predictions = regressor.predict(X_test[:, np.newaxis])
w = regressor.get_weights()
# Out:
# Input shape:  (50, 1)
# Design matrix shape (X_train.shape):  (50, 2)
#
# Epoch  50  |  loss:  113.91175825789448
# Epoch  100  |  loss:  111.91668853709587
# Epoch  150  |  loss:  117.09091736481876
# Epoch  200  |  loss:  110.1235917369471
# ------------------------
# Best epoch  171  |  loss:  105.10710900179518

# %%
plt.figure(figsize=(10, 5))
plt.plot(X, 10 * X - 7, label='real')

plt.scatter(X_train, y_train, label='train')
plt.scatter(X_test, y_test, label='test')
plt.plot(X, X * w[0] + w[-1], label='predicted')
plt.legend()
plt.show()

# %%
plt.plot(l)

# %% [markdown]
# # Логистическая регрессия

# %%
def logit(x, w):
    return np.dot(x, w)

def sigmoid(h):
    return 1. / (1 + np.exp(-h))


class MyLogisticRegression(object):
    
    def __init__(self):
        self.w = None
    
    def fit(self, X, y, n_epoch=100, lr=0.1):
        # Input: X, y
        # Output: computes weights for logistic regression
        # Output classes: {1, -1}
        
        n, k = X.shape
        
        if self.w is None:
            self.w = np.random.randn(k + 1)
        
        # adding intercept column to the new design matrix X_train
        X_train = np.concatenate((np.ones((n, 1)), X), axis=1)
        
        losses = []
        
        for iter_num in range(n_epoch):
            
            z = sigmoid(logit(X_train, self.w))
            grad =  np.dot(X_train.T, (z - y)) / len(y)

            self.w -= grad * lr

            losses.append(self.__loss(y, z))
        
        return losses
        
    def predict_proba(self, X):
        # Input: X
        # Output: predicted class probabilities for the positive class
        n, k = X.shape
        X_ = np.concatenate((np.ones((n, 1)), X), axis=1)
        return sigmoid(logit(X_, self.w))

    def predict(self, X, threshold=0.5):
        return (self.predict_proba(X) >= threshold).astype(int)
    
    def get_weights(self):
        return self.w
      
    def __loss(self, y, p):
        p = np.clip(p, 1e-10, 1 - 1e-10)
        return np.mean(y * np.log(p) + (1 - y) * np.log(1 - p))

# %%
import numpy as np

a = np.array([False, True])
a.astype(int)
# Out:
# array([0, 1])

# %%
import matplotlib.pyplot as plt

from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples=1000, centers=[[-2,0.5],[3,-0.5]], cluster_std=1, random_state=42)

colors = ("red", "green")
colored_y = np.zeros(y.size, dtype=str)

for i, cl in enumerate([0,1]):
    colored_y[y == cl] = str(colors[i])
    
plt.figure(figsize=(15,10))
plt.scatter(X[:, 0], X[:, 1], c=colored_y)
plt.show()

# %%
clf = MyLogisticRegression()

clf.fit(X, y, n_epoch=1000)

w = clf.get_weights()

# %%
from matplotlib.colors import ListedColormap

plt.figure(figsize=(15,8))

eps = 0.1
xx, yy = np.meshgrid(np.linspace(np.min(X[:,0]) - eps, np.max(X[:,0]) + eps, 200),
                     np.linspace(np.min(X[:,1]) - eps, np.max(X[:,1]) + eps, 200))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

Z = Z.reshape(xx.shape)

cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA'])
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)



plt.scatter(X[:, 0], X[:, 1], c=colored_y)
